# %% [markdown]
# def 方法測試

# %%
import pandas as pd

# %%
from textblob import TextBlob

# %%
df1=pd.read_csv('datasetB.tsv', delimiter='\t')

# %%
df1
# Out:
#                                      ID  \
# 0      d468a1f3b12a4fb28dfa957790c0688e
# 1      ed7cfb9186af49ec9a4671bbe0b494b0
# 2      bb5ce0943b044cf4a7161dbd47d993fa
# 3      e0aa58dd0d5a4dcab715c65f0b04aa31
# 4      eb8bf002681c4785822ae3c2c8afa00c
# 5      10fb6b0184364c38b15b9a0b1b785288
# 6      03e3a46edd60422095ffaeff47c2bd5b
# 7      3623fda9eb2f479a8f6abf02be22acb5
# 8      51640e4f1e1e4c14a98f0e2c9293fe5e
# 9      f62d772b73a5453a84f0cebbaf20887e
# 10     f9666f50bef54424817c58378178589f
# 11     9fad9ab332ad4f18a21928d859a07884
# 12     b8782eb52214435184c319797b7d445c
# 13     4fd6a298fa864846bfde2e3a502401eb
# 14     b00fdf3751d0443196dc801391589732
# 15     7f23db3a66c9404eac12142e954f6990
# 16     1634147b87db4b1c9a6d4b7cd09292a7
# 17     7a4f6b3ddae84949b383e5fce8827152
# 18     041230071d514c3dacb112ed871f19a7
# 19     e0a4dead039b481ca6cb057acbac97a3
# 20     cbfc6603000a4e3a8d3bc9dd7095192a
# 21     9808583810d14bbd965f2f31c7d87d11
# ...

# %%
df1.rename(columns={"ID": "ID", "w00": "Char"})
# Out:
#                                      ID  \
# 0      d468a1f3b12a4fb28dfa957790c0688e
# 1      ed7cfb9186af49ec9a4671bbe0b494b0
# 2      bb5ce0943b044cf4a7161dbd47d993fa
# 3      e0aa58dd0d5a4dcab715c65f0b04aa31
# 4      eb8bf002681c4785822ae3c2c8afa00c
# 5      10fb6b0184364c38b15b9a0b1b785288
# 6      03e3a46edd60422095ffaeff47c2bd5b
# 7      3623fda9eb2f479a8f6abf02be22acb5
# 8      51640e4f1e1e4c14a98f0e2c9293fe5e
# 9      f62d772b73a5453a84f0cebbaf20887e
# 10     f9666f50bef54424817c58378178589f
# 11     9fad9ab332ad4f18a21928d859a07884
# 12     b8782eb52214435184c319797b7d445c
# 13     4fd6a298fa864846bfde2e3a502401eb
# 14     b00fdf3751d0443196dc801391589732
# 15     7f23db3a66c9404eac12142e954f6990
# 16     1634147b87db4b1c9a6d4b7cd09292a7
# 17     7a4f6b3ddae84949b383e5fce8827152
# 18     041230071d514c3dacb112ed871f19a7
# 19     e0a4dead039b481ca6cb057acbac97a3
# 20     cbfc6603000a4e3a8d3bc9dd7095192a
# 21     9808583810d14bbd965f2f31c7d87d11
# ...

# %%
df1.head(10)
# Out:
#                                  ID  \
# 0  d468a1f3b12a4fb28dfa957790c0688e
# 1  ed7cfb9186af49ec9a4671bbe0b494b0
# 2  bb5ce0943b044cf4a7161dbd47d993fa
# 3  e0aa58dd0d5a4dcab715c65f0b04aa31
# 4  eb8bf002681c4785822ae3c2c8afa00c
# 5  10fb6b0184364c38b15b9a0b1b785288
# 6  03e3a46edd60422095ffaeff47c2bd5b
# 7  3623fda9eb2f479a8f6abf02be22acb5
# 8  51640e4f1e1e4c14a98f0e2c9293fe5e
# 9  f62d772b73a5453a84f0cebbaf20887e
#
#                                                  w00
# 0   cox Paulette meaningful Berman hove heed civi...
# 1   cox meaningful mucus Berman sprocket venerabl...
# 2   demonstrate meaningful mucus Berman hither de...
# 3   Siegfried demonstrate Paulette hither denotat...
# 4   cox Paulette mucus denotation Isabel jostle b...
# 5  gunk Siegfried Paulette meaningful mucus Berma...
# 6   cox Paulette meaningful Berman venerable civi...
# 7   copperhead demonstrate hither denotation jost...
# 8   demonstrate mucus Berman denotation Crestview...
# ...

# %%
def senti(x):
    return TextBlob(x).sentiment

# %%
df1['senti_score'] = df1['w00'].apply(senti)

# %%
df1.senti_score.head()
# Out:
# 0    (0.39999999999999997, 0.6666666666666666)
# 1                                  (0.45, 0.5)
# 2                                   (0.5, 0.5)
# 3                                  (0.0, 0.55)
# 4                                   (0.0, 0.0)
# Name: senti_score, dtype: object

# %%
df1
# Out:
#                                      ID  \
# 0      d468a1f3b12a4fb28dfa957790c0688e
# 1      ed7cfb9186af49ec9a4671bbe0b494b0
# 2      bb5ce0943b044cf4a7161dbd47d993fa
# 3      e0aa58dd0d5a4dcab715c65f0b04aa31
# 4      eb8bf002681c4785822ae3c2c8afa00c
# 5      10fb6b0184364c38b15b9a0b1b785288
# 6      03e3a46edd60422095ffaeff47c2bd5b
# 7      3623fda9eb2f479a8f6abf02be22acb5
# 8      51640e4f1e1e4c14a98f0e2c9293fe5e
# 9      f62d772b73a5453a84f0cebbaf20887e
# 10     f9666f50bef54424817c58378178589f
# 11     9fad9ab332ad4f18a21928d859a07884
# 12     b8782eb52214435184c319797b7d445c
# 13     4fd6a298fa864846bfde2e3a502401eb
# 14     b00fdf3751d0443196dc801391589732
# 15     7f23db3a66c9404eac12142e954f6990
# 16     1634147b87db4b1c9a6d4b7cd09292a7
# 17     7a4f6b3ddae84949b383e5fce8827152
# 18     041230071d514c3dacb112ed871f19a7
# 19     e0a4dead039b481ca6cb057acbac97a3
# 20     cbfc6603000a4e3a8d3bc9dd7095192a
# 21     9808583810d14bbd965f2f31c7d87d11
# ...
